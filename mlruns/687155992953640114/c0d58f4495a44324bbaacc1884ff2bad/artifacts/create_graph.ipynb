# %%
# Loaded variable 'df' from URI: /Users/jeremyrava/Documents/01 - Projets/fev24_bds_rakuten/mlruns/997841614806310414/33a42c38398e48a5b4b8584550173e91/artifacts/cv_results.csv
import pandas as pd

df = pd.read_csv(
    r"/Users/jeremyrava/Documents/01 - Projets/fev24_bds_rakuten/mlruns/687155992953640114/c0d58f4495a44324bbaacc1884ff2bad/artifacts/cv_results.csv"
)

# %%
display(df.head())
df.info()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      28.014466      0.661098         0.073093        0.002981
# 1      30.070174      0.322812         0.075408        0.002248
# 2      31.463648      1.224129         0.066901        0.000605
# 3      47.533494      1.378291         0.112594        0.007785
# 4      50.551689      0.663006         0.110552        0.003559
#
#    param_colsample_bytree  param_learning_rate  param_max_depth  \
# 0                     0.6                 0.01                3
# 1                     0.6                 0.01                3
# 2                     0.6                 0.01                3
# 3                     0.6                 0.01                3
# 4                     0.6                 0.01                3
#
#    param_n_estimators  param_subsample  \
# 0                  30              0.6
# 1                  30              0.8
# 2                  30              1.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 10))
sns.relplot(
    x="std_test_score",
    y="mean_test_score",
    data=df,
    hue="param_max_depth",
    size="param_learning_rate",
    palette="coolwarm",
    col="param_n_estimators",
    style="param_colsample_bytree",
    col_wrap=2,
)
plt.legend()
plt.show()
plt.savefig(
    r"/Users/jeremyrava/Documents/01 - Projets/fev24_bds_rakuten/mlruns/687155992953640114/c0d58f4495a44324bbaacc1884ff2bad/artifacts/cv_results.png"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
