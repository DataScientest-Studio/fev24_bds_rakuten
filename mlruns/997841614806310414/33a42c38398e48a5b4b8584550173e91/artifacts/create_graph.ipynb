# %%
# Loaded variable 'df' from URI: /Users/jeremyrava/Documents/01 - Projets/fev24_bds_rakuten/mlruns/997841614806310414/33a42c38398e48a5b4b8584550173e91/artifacts/cv_results.csv
import pandas as pd

df = pd.read_csv(
    r"/Users/jeremyrava/Documents/01 - Projets/fev24_bds_rakuten/mlruns/997841614806310414/33a42c38398e48a5b4b8584550173e91/artifacts/cv_results.csv"
)

# %%
display(df.head())
df.info()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      17.100052      0.160392         0.033070        0.001916
# 1      16.801687      0.608815         0.033031        0.002240
# 2      16.766029      0.055550         0.032824        0.001400
# 3      14.571496      0.409206         0.032267        0.002358
# 4      14.454339      0.217773         0.033163        0.001494
#
#   param_criterion  param_max_depth  param_min_samples_leaf  \
# 0            gini              NaN                       1
# 1            gini              NaN                       1
# 2            gini              NaN                       1
# 3            gini              NaN                       2
# 4            gini              NaN                       2
#
#    param_min_samples_split                                             params  \
# 0                        2  {'criterion': 'gini', 'max_depth': None, 'min_...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 10))
sns.relplot(
    x="std_test_score",
    y="mean_test_score",
    data=df,
    hue="param_min_samples_leaf",
    size="param_min_samples_split",
    palette="coolwarm",
    col="param_criterion",
    style="param_max_depth",
    col_wrap=2,
)
plt.legend()
plt.show()
plt.savefig(
    r"/Users/jeremyrava/Documents/01 - Projets/fev24_bds_rakuten/mlruns/997841614806310414/33a42c38398e48a5b4b8584550173e91/artifacts/cv_results.png"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
